# %% [markdown]
# # Get Data

# %%
# !pip install ultralytics
# !pip install roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="nJS7WT2cj6w32SPJgWbq")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(2)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# import shutil

# shutil.move('football-players-detection-2/train',
#             'football-players-detection-2/football-players-detection-2/train')
# shutil.move('football-players-detection-2/test',
#             'football-players-detection-2/football-players-detection-2/test')
# shutil.move('football-players-detection-2/valid',
#             'football-players-detection-2/football-players-detection-2/valid')

# %% [markdown]
# # Get Dataset

# %%
dataset.location
# Out:
# '/content/football-players-detection-2'

# %%
# !yolo task=detect mode=train model=yolov5s.pt data={dataset.location}/data.yaml epochs=50 imgsz=960
# Out:
# PRO TIP 💡 Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
import os
os.listdir("/content/runs/detect/train3/weights")
# Out:
# ['best.pt', 'last.pt']

# %%
from google.colab import files
#files.download('/content/runs/detect/train3/weights/best.pt')
files.download('/content/runs/detect/train3/weights/last.pt')
